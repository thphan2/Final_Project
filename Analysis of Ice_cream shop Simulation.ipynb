# %%
# %matplotlib inline
import pandas as pd
import random
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
import icshop_simulation as sim

# %%
# Given budget and combination of employees, the relationship among profit, waiting time and number of ice-cream
#random.seed(1) # replicate the result this notebook has
for i in range(100):
    sim.simulation(2,1,1,1,1000,"test", False)

# %%
# 1 medium ice_cream ~ 1.5 small ice_cream; 1 large ice_cream ~ 2 small ice_cream in terms of quantity/raw material
# total icecream is calculated after conversion of medium/large icecream numbers
names = ["experienced chef", "new chef", "experienced cashier", "new cashier", "small icecream", \
         "medium icecream", "large icecream", "total icecream", "number of customer", "order waiting time", "prepare waiting time", "waiting time", "profit"]

# %%
data = pd.read_csv("test.csv", names=names)

# %%
data.tail()
# Out:
#     experienced chef  new chef  experienced cashier  new cashier  \
# 95                 2         1                    1            1
# 96                 2         1                    1            1
# 97                 2         1                    1            1
# 98                 2         1                    1            1
# 99                 2         1                    1            1
#
#     small icecream  medium icecream  large icecream  total icecream  \
# 95              91               93             131           492.5
# 96              88               82             133           477.0
# 97              81               70              98           382.0
# 98              62               62             105           365.0
# 99              87               89             145           510.5
#
#     number of customer  order waiting time  prepare waiting time  \
# 95                  70                   0                     9
# 96                  68                   0                    10
# 97                  55                   0                     8
# 98                  51                   0                     9
# 99                  65                   0                    11
#
#     waiting time  profit
# 95             9  1270.0
# 96            11  1208.0
# 97             8   828.0
# 98             9   760.0
# 99            11  1342.0

# %%
plt.scatter(data['waiting time'], data['profit'], s=[n*0.7 for n in data['total icecream']])
plt.xlabel("Waiting time")
plt.ylabel("Profit/day");
plt.show()

# %%
#random.seed(2) # replicate the result this notebook has
for i in range(100):
    sim.simulation(2,1,1,1,5000,"test2", False)

# %%
data2 = pd.read_csv("test.csv", names=names)

# %%
data2.tail()
# Out:
#     experienced chef  new chef  experienced cashier  new cashier  \
# 95                 2         1                    1            1
# 96                 2         1                    1            1
# 97                 2         1                    1            1
# 98                 2         1                    1            1
# 99                 2         1                    1            1
#
#     small icecream  medium icecream  large icecream  total icecream  \
# 95              91               93             131           492.5
# 96              88               82             133           477.0
# 97              81               70              98           382.0
# 98              62               62             105           365.0
# 99              87               89             145           510.5
#
#     number of customer  order waiting time  prepare waiting time  \
# 95                  70                   0                     9
# 96                  68                   0                    10
# 97                  55                   0                     8
# 98                  51                   0                     9
# 99                  65                   0                    11
#
#     waiting time  profit
# 95             9  1270.0
# 96            11  1208.0
# 97             8   828.0
# 98             9   760.0
# 99            11  1342.0

# %%
df=pd.read_csv("sample.csv",names=names)

# %%
df.head()
# Out:
#    experienced chef  new chef  experienced cashier  new cashier  \
# 0                 1         0                    1            0
# 1                 1         0                    1            0
# 2                 1         0                    1            0
# 3                 1         0                    1            0
# 4                 1         0                    1            0
#
#    small icecream  medium icecream  large icecream  total icecream  \
# 0              69               50             100           344.0
# 1              83               73             117           426.5
# 2              83               93             144           510.5
# 3              83               85             123           456.5
# 4             102              116             167           610.0
#
#    number of customer  order waiting time  prepare waiting time  waiting time  \
# 0                  53                   2                    28            30
# 1                  60                   3                    56            59
# 2                  67                   4                    97           102
# 3                  64                   3                    55            58
# 4                  76                  10                   141           151
#
#    profit
# 0  1086.0
# 1  1416.0
# 2  1752.0
# 3  1536.0
# 4  2150.0

# %%
def waitingtime_vs_employee(column1_name:str,column2_name:str):
    plt.figure(figsize=(15,10))
    ax = plt.subplot(111)

    for i in range(min(df[column1_name]),max(df[column1_name])+1):
        for j in range(min(df[column2_name]),max(df[column2_name])+1):
            label=str(i)+" exp & "+str(j)+" non-exp"
            tmp_df=df.loc[(df[column1_name]==i) & (df[column2_name]==j)]["waiting time"]
            ax.plot(np.arange(1,len(tmp_df)+1),tmp_df,label=label)

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.show()

# %%
# waitingtime vs combination of chefs
waitingtime_vs_employee('experienced chef','new chef')

# %%
# waitingtime vs combination of cashiers
waitingtime_vs_employee('experienced cashier','new cashier')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-c6eefde329d0> in <module>()
#       1 # waitingtime vs combination of cashiers
# ----> 2 waitingtime_vs_employee('experienced cashier','new cashier')
#
# <ipython-input-23-5d4c0ad1fc36> in waitingtime_vs_employee(column1_name, column2_name)
#       7             label=str(i)+" exp & "+str(j)+" non-exp"
#       8             tmp_df=df.loc[(df[column1_name]==i) & (df[column2_name]==j)]["waiting time"]
# ----> 9             ax.plot(np.arange(1,len(tmp_df)+1),tmp_df,label=label)
#      10
#      11     # Shrink current axis by 20%
#
# C:\Users\Thuong\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Users\Thuong\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1381
#    1382         for line in self._get_lines(*args, **kwargs):
# -> 1383             self.add_line(line)
#    1384             lines.append(line)
#    1385
#
# C:\Users\Thuong\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1699         self._set_artist_props(line)
#    1700         if line.get_clip_path() is None:
# -> 1701             line.set_clip_path(self.patch)
#    1702
#    1703         self._update_line_limits(line)
#
# C:\Users\Thuong\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     684         if transform is None:
#     685             if isinstance(path, Rectangle):
# --> 686                 self.clipbox = TransformedBbox(Bbox.unit(),
#     687                                                path.get_transform())
#     688                 self._clippath = None
#
# C:\Users\Thuong\Anaconda3\lib\site-packages\matplotlib\transforms.py in unit()
#     815         (1, 1).
#     816         """
# --> 817         return Bbox(np.array([[0.0, 0.0], [1.0, 1.0]], np.float))
#     818
#     819     @staticmethod
#
# C:\Users\Thuong\Anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, points, **kwargs)
#     797         # default or has been mutated; we store the orig points to
#     798         # support the mutated methods
# --> 799         self._points_orig = self._points.copy()
#     800     if DEBUG:
#     801         ___init__ = __init__
#
# KeyboardInterrupt:
