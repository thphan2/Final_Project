# %%
# %matplotlib inline
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
import icshop_simulation as sim

# %%
# demo of simulation time log
sim.simulation(1,2,2,1,5000,"",True)
# Out:
# 12:00:00PM: Nitro Ice-cream Shop opens.
# +++ 12:23:48PM: New customer! Customer 1 arrives.
# === 12:26:17PM: Customer 1 completes ordering.
# *** 12:32:50PM: Ice-cream ready! Customer 1's icecream order is completed!
# +++ 12:57:46PM: New customer! Customer 2 arrives.
# === 13:00:21PM: Customer 2 completes ordering.
# *** 13:06:15PM: Ice-cream ready! Customer 2's icecream order is completed!
# +++ 13:34:55PM: New customer! Customer 3 arrives.
# === 13:38:54PM: Customer 3 completes ordering.
# *** 13:44:48PM: Ice-cream ready! Customer 3's icecream order is completed!
# +++ 14:02:43PM: New customer! Customer 4 arrives.
# === 14:05:25PM: Customer 4 completes ordering.
# *** 14:13:03PM: Ice-cream ready! Customer 4's icecream order is completed!
# +++ 14:59:51PM: New customer! Customer 5 arrives.
# === 15:03:05PM: Customer 5 completes ordering.
# *** 15:06:59PM: Ice-cream ready! Customer 5's icecream order is completed!
# +++ 15:09:06PM: New customer! Customer 6 arrives.
# +++ 15:10:45PM: New customer! Customer 7 arrives.
# +++ 15:11:56PM: New customer! Customer 8 arrives.
# === 15:13:02PM: Customer 6 completes ordering.
# === 15:13:08PM: Customer 7 completes ordering.
# === 15:14:26PM: Customer 8 completes ordering.
# *** 15:16:23PM: Ice-cream ready! Customer 6's icecream order is completed!
# *** 15:21:47PM: Ice-cream ready! Customer 7's icecream order is completed!
# *** 15:26:09PM: Ice-cream ready! Customer 8's icecream order is completed!
# +++ 15:28:05PM: New customer! Customer 9 arrives.
# +++ 15:29:00PM: New customer! Customer 10 arrives.
# === 15:31:23PM: Customer 9 completes ordering.
# === 15:32:56PM: Customer 10 completes ordering.
# +++ 15:34:14PM: New customer! Customer 11 arrives.
# +++ 15:34:50PM: New customer! Customer 12 arrives.
# +++ 15:35:11PM: New customer! Customer 13 arrives.
# === 15:37:15PM: Customer 11 completes ordering.
# *** 15:37:56PM: Ice-cream ready! Customer 9's icecream order is completed!
# === 15:37:58PM: Customer 13 completes ordering.
# === 15:38:51PM: Customer 12 completes ordering.
# *** 15:41:13PM: Ice-cream ready! Customer 10's icecream order is completed!
# +++ 15:42:49PM: New customer! Customer 14 arrives.
# *** 15:45:09PM: Ice-cream ready! Customer 11's icecream order is completed!
# +++ 15:45:37PM: New customer! Customer 15 arrives.
# === 15:46:08PM: Customer 14 completes ordering.
# === 15:48:48PM: Customer 15 completes ordering.
# +++ 15:48:52PM: New customer! Customer 16 arrives.
# +++ 15:48:54PM: New customer! Customer 17 arrives.
# === 15:50:52PM: Customer 17 completes ordering.
# *** 15:50:59PM: Ice-cream ready! Customer 13's icecream order is completed!
# === 15:51:00PM: Customer 16 completes ordering.
# *** 15:55:00PM: Ice-cream ready! Customer 12's icecream order is completed!
# *** 15:59:50PM: Ice-cream ready! Customer 14's icecream order is completed!
# +++ 16:01:19PM: New customer! Customer 18 arrives.
# +++ 16:04:10PM: New customer! Customer 19 arrives.
# *** 16:04:12PM: Ice-cream ready! Customer 15's icecream order is completed!
# +++ 16:04:58PM: New customer! Customer 20 arrives.
# === 16:05:06PM: Customer 18 completes ordering.
# *** 16:06:48PM: Ice-cream ready! Customer 17's icecream order is completed!
# === 16:06:50PM: Customer 19 completes ordering.
# === 16:07:30PM: Customer 20 completes ordering.
# +++ 16:10:13PM: New customer! Customer 21 arrives.
# *** 16:10:44PM: Ice-cream ready! Customer 16's icecream order is completed!
# === 16:12:40PM: Customer 21 completes ordering.
# +++ 16:14:30PM: New customer! Customer 22 arrives.
# *** 16:14:40PM: Ice-cream ready! Customer 18's icecream order is completed!
# +++ 16:15:56PM: New customer! Customer 23 arrives.
# === 16:17:45PM: Customer 22 completes ordering.
# === 16:18:29PM: Customer 23 completes ordering.
# +++ 16:19:31PM: New customer! Customer 24 arrives.
# *** 16:19:32PM: Ice-cream ready! Customer 19's icecream order is completed!
# === 16:22:50PM: Customer 24 completes ordering.
# *** 16:23:54PM: Ice-cream ready! Customer 20's icecream order is completed!
# +++ 16:26:19PM: New customer! Customer 25 arrives.
# *** 16:26:31PM: Ice-cream ready! Customer 21's icecream order is completed!
# +++ 16:26:35PM: New customer! Customer 26 arrives.
# === 16:28:48PM: Customer 25 completes ordering.
# === 16:28:59PM: Customer 26 completes ordering.
# *** 16:30:27PM: Ice-cream ready! Customer 22's icecream order is completed!
# *** 16:31:58PM: Ice-cream ready! Customer 24's icecream order is completed!
# *** 16:33:45PM: Ice-cream ready! Customer 23's icecream order is completed!
# +++ 16:38:04PM: New customer! Customer 27 arrives.
# *** 16:38:07PM: Ice-cream ready! Customer 25's icecream order is completed!
# +++ 16:38:23PM: New customer! Customer 28 arrives.
# +++ 16:38:34PM: New customer! Customer 29 arrives.
# +++ 16:39:42PM: New customer! Customer 30 arrives.
# === 16:40:50PM: Customer 27 completes ordering.
# *** 16:41:17PM: Ice-cream ready! Customer 26's icecream order is completed!
# === 16:42:04PM: Customer 28 completes ordering.
# === 16:42:09PM: Customer 29 completes ordering.
# === 16:44:14PM: Customer 30 completes ordering.
# +++ 16:45:31PM: New customer! Customer 31 arrives.
# *** 16:47:23PM: Ice-cream ready! Customer 27's icecream order is completed!
# +++ 16:47:30PM: New customer! Customer 32 arrives.
# === 16:48:01PM: Customer 31 completes ordering.
# +++ 16:49:30PM: New customer! Customer 33 arrives.
# === 16:49:38PM: Customer 32 completes ordering.
# +++ 16:51:03PM: New customer! Customer 34 arrives.
# *** 16:51:28PM: Ice-cream ready! Customer 29's icecream order is completed!
# *** 16:51:45PM: Ice-cream ready! Customer 28's icecream order is completed!
# +++ 16:52:03PM: New customer! Customer 35 arrives.
# === 16:52:49PM: Customer 33 completes ordering.
# === 16:54:10PM: Customer 35 completes ordering.
# === 16:54:24PM: Customer 34 completes ordering.
# *** 16:55:04PM: Ice-cream ready! Customer 30's icecream order is completed!
# +++ 16:58:15PM: New customer! Customer 36 arrives.
# *** 16:58:19PM: Ice-cream ready! Customer 31's icecream order is completed!
# +++ 16:58:27PM: New customer! Customer 37 arrives.
# === 17:00:14PM: Customer 36 completes ordering.
# === 17:00:56PM: Customer 37 completes ordering.
# *** 17:02:41PM: Ice-cream ready! Customer 32's icecream order is completed!
# *** 17:07:10PM: Ice-cream ready! Customer 33's icecream order is completed!
# *** 17:15:00PM: Ice-cream ready! Customer 35's icecream order is completed!
# *** 17:22:21PM: Ice-cream ready! Customer 34's icecream order is completed!
# *** 17:26:43PM: Ice-cream ready! Customer 36's icecream order is completed!
# *** 17:31:05PM: Ice-cream ready! Customer 37's icecream order is completed!
# +++ 18:03:17PM: New customer! Customer 38 arrives.
# === 18:05:56PM: Customer 38 completes ordering.
# *** 18:11:50PM: Ice-cream ready! Customer 38's icecream order is completed!
# +++ 18:29:26PM: New customer! Customer 39 arrives.
# === 18:32:05PM: Customer 39 completes ordering.
# *** 18:35:21PM: Ice-cream ready! Customer 39's icecream order is completed!
# +++ 18:49:21PM: New customer! Customer 40 arrives.
# === 18:52:54PM: Customer 40 completes ordering.
# *** 18:57:21PM: Ice-cream ready! Customer 40's icecream order is completed!
# +++ 19:01:06PM: New customer! Customer 41 arrives.
# +++ 19:03:08PM: New customer! Customer 42 arrives.
# === 19:03:18PM: Customer 41 completes ordering.
# === 19:05:28PM: Customer 42 completes ordering.
# *** 19:09:12PM: Ice-cream ready! Customer 41's icecream order is completed!
# +++ 19:09:14PM: New customer! Customer 43 arrives.
# +++ 19:09:24PM: New customer! Customer 44 arrives.
# *** 19:10:34PM: Ice-cream ready! Customer 42's icecream order is completed!
# === 19:11:45PM: Customer 44 completes ordering.
# +++ 19:13:02PM: New customer! Customer 45 arrives.
# === 19:13:09PM: Customer 43 completes ordering.
# === 19:15:58PM: Customer 45 completes ordering.
# +++ 19:16:35PM: New customer! Customer 46 arrives.
# *** 19:17:39PM: Ice-cream ready! Customer 44's icecream order is completed!
# === 19:19:08PM: Customer 46 completes ordering.
# *** 19:22:56PM: Ice-cream ready! Customer 43's icecream order is completed!
# +++ 19:23:16PM: New customer! Customer 47 arrives.
# +++ 19:24:17PM: New customer! Customer 48 arrives.
# +++ 19:24:47PM: New customer! Customer 49 arrives.
# +++ 19:24:54PM: New customer! Customer 50 arrives.
# === 19:27:17PM: Customer 47 completes ordering.
# === 19:27:28PM: Customer 48 completes ordering.
# *** 19:27:30PM: Ice-cream ready! Customer 45's icecream order is completed!
# +++ 19:27:45PM: New customer! Customer 51 arrives.
# === 19:28:01PM: Customer 49 completes ordering.
# === 19:30:19PM: Customer 50 completes ordering.
# *** 19:30:21PM: Ice-cream ready! Customer 46's icecream order is completed!
# === 19:31:25PM: Customer 51 completes ordering.
# *** 19:32:27PM: Ice-cream ready! Customer 47's icecream order is completed!
# +++ 19:33:02PM: New customer! Customer 52 arrives.
# *** 19:35:25PM: Ice-cream ready! Customer 48's icecream order is completed!
# === 19:35:29PM: Customer 52 completes ordering.
# +++ 19:39:17PM: New customer! Customer 53 arrives.
# +++ 19:40:18PM: New customer! Customer 54 arrives.
# *** 19:42:24PM: Ice-cream ready! Customer 49's icecream order is completed!
# +++ 19:42:37PM: New customer! Customer 55 arrives.
# === 19:42:36PM: Customer 53 completes ordering.
# === 19:43:34PM: Customer 54 completes ordering.
# +++ 19:43:37PM: New customer! Customer 56 arrives.
# === 19:46:31PM: Customer 55 completes ordering.
# *** 19:47:16PM: Ice-cream ready! Customer 50's icecream order is completed!
# === 19:47:33PM: Customer 56 completes ordering.
# +++ 19:51:00PM: New customer! Customer 57 arrives.
# *** 19:51:08PM: Ice-cream ready! Customer 51's icecream order is completed!
# *** 19:53:12PM: Ice-cream ready! Customer 52's icecream order is completed!
# === 19:54:54PM: Customer 57 completes ordering.
# *** 19:55:26PM: Ice-cream ready! Customer 53's icecream order is completed!
# +++ 19:55:57PM: New customer! Customer 58 arrives.
# === 19:58:50PM: Customer 58 completes ordering.
# *** 19:59:54PM: Ice-cream ready! Customer 54's icecream order is completed!
# +++ 20:04:44PM: New customer! Customer 59 arrives.
# *** 20:07:02PM: Ice-cream ready! Customer 55's icecream order is completed!
# === 20:08:26PM: Customer 59 completes ordering.
# +++ 20:09:29PM: New customer! Customer 60 arrives.
# +++ 20:09:45PM: New customer! Customer 61 arrives.
# *** 20:10:58PM: Ice-cream ready! Customer 56's icecream order is completed!
# === 20:11:45PM: Customer 60 completes ordering.
# +++ 20:13:12PM: New customer! Customer 62 arrives.
# === 20:13:13PM: Customer 61 completes ordering.
# *** 20:14:09PM: Ice-cream ready! Customer 57's icecream order is completed!
# === 20:16:09PM: Customer 62 completes ordering.
# *** 20:17:52PM: Ice-cream ready! Customer 58's icecream order is completed!
# +++ 20:20:06PM: New customer! Customer 63 arrives.
# *** 20:21:48PM: Ice-cream ready! Customer 59's icecream order is completed!
# === 20:23:42PM: Customer 63 completes ordering.
# *** 20:25:05PM: Ice-cream ready! Customer 60's icecream order is completed!
# +++ 20:25:09PM: New customer! Customer 64 arrives.
# === 20:28:07PM: Customer 64 completes ordering.
# *** 20:29:27PM: Ice-cream ready! Customer 61's icecream order is completed!
# +++ 20:29:29PM: New customer! Customer 65 arrives.
# *** 20:29:40PM: Ice-cream ready! Customer 62's icecream order is completed!
# === 20:33:15PM: Customer 65 completes ordering.
# *** 20:35:13PM: Ice-cream ready! Customer 63's icecream order is completed!
# *** 20:40:23PM: Ice-cream ready! Customer 64's icecream order is completed!
# *** 20:44:28PM: Ice-cream ready! Customer 65's icecream order is completed!
# +++ 21:03:05PM: New customer! Customer 66 arrives.
# === 21:07:05PM: Customer 66 completes ordering.
# +++ 21:08:11PM: New customer! Customer 67 arrives.
# === 21:10:39PM: Customer 67 completes ordering.
# *** 21:12:07PM: Ice-cream ready! Customer 66's icecream order is completed!
# +++ 21:13:33PM: New customer! Customer 68 arrives.
# === 21:16:44PM: Customer 68 completes ordering.
# *** 21:21:17PM: Ice-cream ready! Customer 67's icecream order is completed!
# +++ 21:25:39PM: New customer! Customer 69 arrives.
# *** 21:25:39PM: Ice-cream ready! Customer 68's icecream order is completed!
# === 21:27:52PM: Customer 69 completes ordering.
# *** 21:34:25PM: Ice-cream ready! Customer 69's icecream order is completed!
# 21:45:00PM: Shop is closing in 15 minutes, no new orders accepted.
# Finishing the remaining orders...
# 22:00:00PM: All orders completed.
# There are 69 customers coming in today. Average waiting time: 15 minutes.
# Total revenue is: $2,076 dollars. Today's profit is: $1,286.0
# Icecream Shop closes for the day. See you again!

# %%
# column names
names = ["experienced chef", "new chef", "experienced cashier", "new cashier", "small icecream", \
         "medium icecream", "large icecream", "total icecream", "number of customer", "order waiting time", \
         "prepare waiting time", "waiting time", "profit"]

# %%
data = pd.read_csv("sample2.csv", names=names)

# %%
# 1 medium ice_cream ~ 1.5 small ice_cream; 1 large ice_cream ~ 2 small ice_cream in terms of quantity/raw material
# total icecream is calculated after conversion of medium/large icecream numbers
data.head()
# Out:
#    experienced chef  new chef  experienced cashier  new cashier  \
# 0                 1         0                    1            0
# 1                 1         0                    1            0
# 2                 1         0                    1            0
# 3                 1         0                    1            0
# 4                 1         0                    1            0
#
#    small icecream  medium icecream  large icecream  total icecream  \
# 0              83               85             141           492.5
# 1              74               74             122           429.0
# 2              60               72             112           392.0
# 3              90               81             143           497.5
# 4              64               75             106           388.5
#
#    number of customer  order waiting time  prepare waiting time  waiting time  \
# 0                  63                   3                   103           106
# 1                  59                   1                    70            71
# 2                  55                   2                    45            47
# 3                  71                   8                   102           110
# 4                  56                   4                    37            41
#
#    profit
# 0  1680.0
# 1  1426.0
# 2  1278.0
# 3  1700.0
# 4  1264.0

# %%
def profit_waitingtime(column1_name:str,column2_name:str, column3_name:str):
    plt.figure(figsize=(10,8))
    plt.scatter(data[column1_name], data[column2_name], s=[n/5 for n in data[column3_name]])
#     fig = plot.figure()
#     ax = fig.add_subplot(111)

#     for i in range(min(df[column1_name]),max(df[column1_name])+1):
#         for j in range(min(df[column2_name]),max(df[column2_name])+1):
#             label=str(i)+" exp & "+str(j)+" non-exp"
#             tmp_df=df.loc[(df[column1_name]==i) & (df[column2_name]==j)]["waiting time"]
#             ax.plot(np.arange(1,len(tmp_df)+1),tmp_df,label=label)

#     # Shrink current axis by 20%
#     box = ax.get_position()
#     ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#     # Put a legend to the right of the current axis
#     ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.show()

# %%
profit_waitingtime('waiting time','profit','total icecream')

# %%
plt.scatter(1/data['waiting time'], data['profit'], s=[n for n in data['total icecream']])
plt.xlabel("Waiting time")
plt.ylabel("Profit/day");

# %%
df=pd.read_csv("sample.csv",names=names)

# %%
df.head()
# Out:
#    experienced chef  new chef  experienced cashier  new cashier  \
# 0                 1         0                    1            0
# 1                 1         0                    1            0
# 2                 1         0                    1            0
# 3                 1         0                    1            0
# 4                 1         0                    1            0
#
#    small icecream  medium icecream  large icecream  total icecream  \
# 0              68               76             128           438.0
# 1              98               93             144           525.5
# 2              79               92             151           519.0
# 3              64               70             114           397.0
# 4              76               65             114           401.5
#
#    number of customer  order waiting time  prepare waiting time  waiting time  \
# 0                  59                   3                    72            75
# 1                  68                   6                   115           121
# 2                  60                   3                    99           102
# 3                  53                   3                    58            61
# 4                  53                   2                    52            54
#
#    profit
# 0  1462.0
# 1  1812.0
# 2  1786.0
# 3  1298.0
# 4  1316.0

# %%
def waitingtime_vs_employee(column1_name:str,column2_name:str):
    plt.figure(figsize=(15,10))
    ax = plt.subplot(111)

    for i in range(min(df[column1_name]),max(df[column1_name])+1):
        for j in range(min(df[column2_name]),max(df[column2_name])+1):
            label=str(i)+" exp & "+str(j)+" non-exp"
            tmp_df=df.loc[(df[column1_name]==i) & (df[column2_name]==j)]["waiting time"]
            ax.plot(np.arange(1,len(tmp_df)+1),tmp_df,label=label)

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.show()

# %%
# waitingtime vs combination of chefs
waitingtime_vs_employee('experienced chef','new chef')

# %%
# waitingtime vs combination of cashiers
waitingtime_vs_employee('experienced cashier','new cashier')
